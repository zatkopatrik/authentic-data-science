# %% [markdown]
# # 1 Introduction to this notebook
#
#
#
# # 1.1 Implicit type conversion
#
# Inspecting variable´s data type using type() function
#
# Examples:
# subtracting the variables
# integer + float
# string + string
#
# Introducing basic data types:
# integers
# The definition
# Examples
#
# floats
# The definition
# Examples
#
# strings
# The definition
# Creating strings using apostrophes
# Examples
#
# Boolean
# The definition
# Examples
#
#
# # 1.2 Explicit type conversion alias Type Casting
# Defining data type explicitly
# int(), float(), str(), round()
#
# Examples:
# 3.2.1 Special data type: Datetime
# Introducing datetime module that helps with working with dates and times
# 3 classes:
#
# datetime
# how to create datetime object
# attributes (year, month, day, hour, minute)
# parse datetime to strings (datetime.strftime())
# parse strings as dates (datetime.strptime())
# mathematical operations
# date
# time
# how to create time object
# comparison of time objects
# built-in functions, mathematical operations
#
# # 1.3 Here comes the bug
# Introduction
#
# Errors in the code and debugging
# explaining Traceback error message
#
# 		Examples
