# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Data/avocado.csv')

# %%
data
# Out:
#              Date  AveragePrice  Total Volume  Small Hass Avocado  \
# 0      2015-01-04          1.75      27365.89             9307.34
# 1      2015-01-04          1.49      17723.17             1189.35
# 2      2015-01-04          1.68       2896.72              161.68
# 3      2015-01-04          1.52      54956.80             3013.04
# 4      2015-01-04          1.64       1505.12                1.27
# ...           ...           ...           ...                 ...
# 18244  2018-03-25          1.36     908202.13           142681.06
# 18245  2018-03-25          0.70    9010588.32          3999735.71
# 18246  2018-03-25          1.42     163496.70            29253.30
# 18247  2018-03-25          1.70     190257.38            29644.09
# 18248  2018-03-25          1.34    1774776.77            63905.98
#
#        Large Hass Avocado  Extra Large Hass Avocado  Total Bags  Small Bags  \
# 0                 3844.81                    615.28    13598.46    13061.10
# ...

# %%
data.isnull().sum()
# Out:
# Date                        0
# AveragePrice                0
# Total Volume                0
# Small Hass Avocado          0
# Large Hass Avocado          0
# Extra Large Hass Avocado    0
# Total Bags                  0
# Small Bags                  0
# Large Bags                  0
# XLarge Bags                 0
# type                        0
# year                        0
# region                      0
# dtype: int64

# %%
# 10 % missing values
data['region'] = data['region'].sample(frac = 0.9)

# %%
# 20 % missing values
data['Small Bags'] = data['Small Bags'].sample(frac = 0.8)

# %%
data.drop('Total Bags', axis = 1, inplace = True)

# %%
data.isnull().sum()
# Out:
# Date                           0
# AveragePrice                   0
# Total Volume                   0
# Small Hass Avocado             0
# Large Hass Avocado             0
# Extra Large Hass Avocado       0
# Small Bags                  3650
# Large Bags                     0
# XLarge Bags                    0
# type                           0
# year                           0
# region                      1825
# dtype: int64

# %%
data.sample(20)
# Out:
#              Date  AveragePrice  Total Volume  Small Hass Avocado  \
# 2846   2015-07-05          2.16       3669.96              278.99
# 16888  2017-12-31          1.36      25590.34             9524.47
# 2286   2015-05-31          1.27     419158.75           296763.96
# 1983   2015-05-10          1.09     141860.18            52698.39
# 6020   2016-01-24          1.07     453559.54              852.07
# 15426  2017-09-24          2.08       7802.86              226.04
# 16658  2017-12-17          1.26     394608.36             8588.72
# 1877   2015-05-03          1.54      26104.52             9002.35
# 13420  2017-05-21          0.91    1291606.06           728358.74
# 6772   2016-03-13          2.27      25229.74             1352.64
# 50     2015-01-04          1.01      80034.32            44562.12
# 7106   2016-04-03          1.04     402546.34           196164.23
# 14426  2017-07-23          1.21     211384.21            95944.35
# ...

# %%
data.to_csv('avocado_missing.csv', index = False)

# %%
# return only rows with missing values
data[data.iloc[:, 10]=='NaN']
# Out:
# C:\Users\gecel\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Empty DataFrame
# Columns: [Date, AveragePrice, Total Volume, Small Hass Avocado, Large Hass Avocado, Extra Large Hass Avocado, Small Bags, Large Bags, XLarge Bags, type, year, region]
# Index: []

# %%
# Adding missing values randomly for the entire df
nan_df = np.random.random(data.shape)<0.2

# %%
nan_df.sum()
# Out:
# 43822

# %%
df_missing = data.mask(np.random.random(data.shape)<0.2)

# %%
df_missing
# Out:
#              Date  AveragePrice  Total Volume  Small Hass Avocado  \
# 0      2015-01-04          1.75      27365.89             9307.34
# 1      2015-01-04           NaN      17723.17             1189.35
# 2      2015-01-04          1.68       2896.72              161.68
# 3      2015-01-04          1.52           NaN                 NaN
# 4      2015-01-04          1.64       1505.12                 NaN
# ...           ...           ...           ...                 ...
# 18244  2018-03-25          1.36     908202.13                 NaN
# 18245  2018-03-25          0.70    9010588.32          3999735.71
# 18246  2018-03-25           NaN     163496.70            29253.30
# 18247  2018-03-25          1.70           NaN            29644.09
# 18248  2018-03-25          1.34    1774776.77                 NaN
#
#        Large Hass Avocado  Extra Large Hass Avocado  Small Bags  Large Bags  \
# 0                 3844.81                    615.28    13061.10      537.36
# ...

# %%
df_missing.isnull().sum()
# Out:
# Date                        3693
# AveragePrice                3595
# Total Volume                3617
# Small Hass Avocado          3633
# Large Hass Avocado          3722
# Extra Large Hass Avocado    3674
# Small Bags                  6603
# Large Bags                  3637
# XLarge Bags                 3696
# type                        3685
# year                        3667
# region                      5140
# dtype: int64
